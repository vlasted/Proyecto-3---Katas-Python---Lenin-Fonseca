# %% [markdown]
# # Proyecto 3 - Katas Python
#
# **Autor:** Lenin Fonseca
#
# Este notebook recoge la resolución de las katas de Python del Proyecto 3.
#
# ## Contenido
# Este proyecto incluye ejercicios para practicar:
#
# - tipos de datos básicos
# - estructuras de datos
# - condicionales
# - iteración
# - funciones
# - programación orientada a objetos
# - módulos
# - buenas prácticas

# %%
from functools import reduce

# %% [markdown]
# ## Ejercicio 1
#
# Escribe una función que reciba una cadena de texto como parámetro y devuelva un diccionario con las frecuencias de cada letra en la cadena. Los espacios no deben ser considerados.

# %% [markdown]
# ### Nota explicativa
# Se crea un diccionario para contar cuántas veces aparece cada letra. Primero se eliminan los espacios y se pasa el texto a minúsculas para que el conteo sea más uniforme. Después se recorre cada letra y se suma una unidad si ya existe en el diccionario.

# %%
def frecuencia_letras(texto):
    frecuencias = {}
    texto_limpio = texto.replace(" ", "").lower()

    for letra in texto_limpio:
        if letra in frecuencias:
            frecuencias[letra] += 1
        else:
            frecuencias[letra] = 1

    return frecuencias

# %%
print("#1", frecuencia_letras("Hola Antonio"))
# Out:
# #1 {'h': 1, 'o': 3, 'l': 1, 'a': 2, 'n': 2, 't': 1, 'i': 1}

# %% [markdown]
# ## Ejercicio 2
#
# Dada una lista de números, obtén una nueva lista con el doble de cada valor. Usa la función `map()`.

# %% [markdown]
# ### Nota explicativa
# Se usa `map()` para recorrer la lista y multiplicar cada número por 2. Después se convierte el resultado en lista con `list()`.

# %%
def doblar_valores(lista):
    return list(map(lambda numero: numero * 2, lista))

# %%
print("#2", doblar_valores([1, 2, 3, 4]))
# Out:
# #2 [2, 4, 6, 8]

# %% [markdown]
# ## Ejercicio 3
#
# Escribe una función que tome una lista de palabras y una palabra objetivo como parámetros. La función debe devolver una lista con todas las palabras de la lista original que contengan la palabra objetivo.

# %% [markdown]
# ### Nota explicativa
# Se busca si una palabra objetivo está contenida dentro de cada palabra de la lista. Para evitar problemas con mayúsculas y minúsculas, se convierte todo a minúsculas antes de comparar.

# %%
def buscar_palabras(lista_palabras, objetivo):
    objetivo = objetivo.lower()
    return [palabra for palabra in lista_palabras if objetivo in palabra.lower()]

# %%
print("#3", buscar_palabras(["casa", "casco", "perro", "casual"], "cas"))
# Out:
# #3 ['casa', 'casco', 'casual']

# %% [markdown]
# ## Ejercicio 4
#
# Genera una función que calcule la diferencia entre los valores de dos listas. Usa la función `map()`.

# %% [markdown]
# ### Nota explicativa
# Se calcula la diferencia entre dos listas posición por posición usando `map()`. Antes de hacerlo, se comprueba que ambas listas tengan la misma longitud para evitar errores.

# %%
def diferencia_listas(lista1, lista2):
    if len(lista1) != len(lista2):
        raise ValueError("Las dos listas deben tener la misma longitud.")
    return list(map(lambda x, y: x - y, lista1, lista2))

# %%
print("#4", diferencia_listas([10, 20, 30], [1, 2, 3]))
# Out:
# #4 [9, 18, 27]

# %% [markdown]
# ## Ejercicio 5
#
# Escribe una función que tome una lista de números como parámetro y un valor opcional `nota_aprobado` (por defecto 5). La función debe calcular la media y devolver una tupla con la media y el estado.

# %% [markdown]
# ### Nota explicativa
# Se calcula la media de una lista de números y después se compara con la nota mínima para aprobar. La función devuelve una tupla con dos valores: la media y el estado final.

# %%
def calcular_media_y_estado(lista_numeros, nota_aprobado=5):
    if len(lista_numeros) == 0:
        return (0, "suspenso")

    media = sum(lista_numeros) / len(lista_numeros)
    estado = "aprobado" if media >= nota_aprobado else "suspenso"
    return (media, estado)

# %%
print("#5", calcular_media_y_estado([6, 7, 8]))
# Out:
# #5 (7.0, 'aprobado')

# %% [markdown]
# ## Ejercicio 6
#
# Escribe una función que calcule el factorial de un número de manera recursiva.

# %% [markdown]
# ### Nota explicativa
# Se usa recursividad. La función se llama a sí misma hasta llegar al caso base, que ocurre cuando el número es 0 o 1. También se controla que no se introduzcan números negativos.

# %%
def factorial_recursivo(numero):
    if numero < 0:
        raise ValueError("El factorial no está definido para números negativos.")
    if numero == 0 or numero == 1:
        return 1
    return numero * factorial_recursivo(numero - 1)

# %%
print("#6", factorial_recursivo(5))
# Out:
# #6 120

# %% [markdown]
# ## Ejercicio 7
#
# Genera una función que convierta una lista de tuplas a una lista de strings. Usa la función `map()`.

# %% [markdown]
# ### Nota explicativa
# Se usa `map()` para transformar cada tupla en un string. Para ello, cada elemento de la tupla se convierte a texto y luego se une con `" ".join(...)`.

# %%
def tuplas_a_strings(lista_tuplas):
    return list(map(lambda tupla: " ".join(map(str, tupla)), lista_tuplas))

# %%
print("#7", tuplas_a_strings([(1, 2), ("hola", "mundo"), ("Python", 3)]))
# Out:
# #7 ['1 2', 'hola mundo', 'Python 3']

# %% [markdown]
# ## Ejercicio 8
#
# Escribe un programa que pida al usuario dos números e intente dividirlos. Si el usuario ingresa un valor no numérico o intenta dividir por cero, maneja esas excepciones de manera adecuada y muestra un mensaje indicando si la división fue exitosa o no.

# %% [markdown]
# ### Nota explicativa
# Usa `input()` para pedir dos números al usuario. Después se convierten con `float()` y se intenta hacer la división. Se controlan dos errores posibles: que el usuario escriba texto en vez de un número y que intente dividir entre cero.

# %%
def dividir_con_excepciones():
    try:
        numero1 = float(input("Introduce el primer número: "))
        numero2 = float(input("Introduce el segundo número: "))
        resultado = numero1 / numero2
        print(f"La división fue exitosa. Resultado: {resultado}")
    except ValueError:
        print("Error: debes introducir valores numéricos.")
    except ZeroDivisionError:
        print("Error: no se puede dividir entre cero.")

# %%
dividir_con_excepciones()
# Out:
# La división fue exitosa. Resultado: 5.0

# %%
print("Hola!!!!")
# Out:
# 18

# %% [markdown]
# ## Ejercicio 9
#
# Escribe una función que tome una lista de nombres de mascotas como parámetro y devuelva una nueva lista excluyendo ciertas mascotas prohibidas en España. La lista de mascotas a excluir es:
# `["Mapache", "Tigre", "Serpiente Pitón", "Cocodrilo", "Oso"]`

# %% [markdown]
# ### Nota explicativa
# Se usa `filter()` para eliminar de la lista las mascotas prohibidas. La función devuelve una nueva lista solo con las mascotas permitidas.

# %%
def filtrar_mascotas_permitidas(lista_mascotas):
    prohibidas = ["Mapache", "Tigre", "Serpiente Pitón", "Cocodrilo", "Oso"]
    return list(filter(lambda mascota: mascota not in prohibidas, lista_mascotas))

# %%
print("#9", filtrar_mascotas_permitidas(["Perro", "Mapache", "Gato", "Oso", "Loro"]))
# Out:
# #9 ['Perro', 'Gato', 'Loro']

# %% [markdown]
# ## Ejercicio 10
#
# Escribe una función que reciba una lista de números y calcule su promedio. Si la lista está vacía, lanza una excepción personalizada y maneja el error adecuadamente.

# %% [markdown]
# ### Nota explicativa
# Se calcula el promedio de una lista, pero si la lista está vacía se lanza una excepción personalizada llamada `ListaVaciaError`. De esta forma se controla mejor ese caso especial.

# %%
class ListaVaciaError(Exception):
    pass

def calcular_promedio(lista_numeros):
    if len(lista_numeros) == 0:
        raise ListaVaciaError("La lista está vacía.")

    return sum(lista_numeros) / len(lista_numeros)

# %%
try:
    print("#10", calcular_promedio([5, 10, 15]))
except ListaVaciaError as error:
    print("#10", error)
# Out:
# #10 10.0

# %% [markdown]
# ## Ejercicio 11
#
# Escribe un programa que pida al usuario que introduzca su edad. Si el usuario ingresa un valor no numérico o un valor fuera del rango esperado (por ejemplo, menor que 0 o mayor que 120), maneja las excepciones adecuadamente.

# %% [markdown]
# ### Nota explicativa
# Usa `input()` y manejo de excepciones.
# Primero se intenta convertir la edad a entero y luego se comprueba que esté dentro de un rango válido entre 0 y 120.

# %%
def validar_edad():
    try:
        edad = int(input("Introduce tu edad: "))

        if edad < 0 or edad > 120:
            raise ValueError("La edad debe estar entre 0 y 120.")

        print(f"Edad válida: {edad}")
    except ValueError as error:
        print(f"Error: {error}")

# %%
validar_edad()
# Out:
# Edad válida: 11

# %%
print("Hello!!!")
# Out:
# Hello!!!

# %% [markdown]
# ## Ejercicio 12
#
# Genera una función que, al recibir una frase, devuelva una lista con la longitud de cada palabra. Usa la función `map()`.

# %% [markdown]
# ### Nota explicativa
# Se separa la frase en palabras usando `split()`. Después se usa `map()` para obtener la longitud de cada palabra y devolverlo como una lista.

# %%
def longitud_palabras(frase):
    palabras = frase.split()
    return list(map(len, palabras))

# %%
print("#12", longitud_palabras("Hello mundo"))
# Out:
# #12 [5, 5]

# %% [markdown]
# ## Ejercicio 13
#
# Genera una función que, para un conjunto de caracteres, devuelva una lista de tuplas con cada letra en mayúsculas y minúsculas. Las letras no pueden estar repetidas. Usa la función `map()`.

# %% [markdown]
# ### Nota explicativa
# Primero se eliminan los caracteres repetidos usando `set()`. Después se transforma cada carácter en una tupla formada por su versión en mayúscula y en minúscula mediante `map()`.

# %%
def letras_mayus_minus(caracteres):
    letras_unicas = list(set(caracteres))
    return list(map(lambda letra: (letra.upper(), letra.lower()), letras_unicas))

# %%
print("#13", letras_mayus_minus("abracadabra"))
# Out:
# #13 [('D', 'd'), ('A', 'a'), ('C', 'c'), ('B', 'b'), ('R', 'r')]

# %% [markdown]
# ## Ejercicio 14
#
# Crea una función que retorne las palabras de una lista que comiencen con una letra en específico. Usa la función `filter()`.

# %% [markdown]
# ### Nota explicativa
# Se usa `filter()` para devolver únicamente las palabras que empiecen por una letra concreta. Antes de comparar, tanto la letra como las palabras se convierten a minúsculas.

# %%
def palabras_por_letra(lista_palabras, letra):
    letra = letra.lower()
    return list(filter(lambda palabra: palabra.lower().startswith(letra), lista_palabras))

# %%
print("#14", palabras_por_letra(["casa", "coche", "perro", "camino"], "c"))
# Out:
# #14 ['casa', 'coche', 'camino']

# %% [markdown]
# ## Ejercicio 15
#
# Crea una función lambda que sume 3 a cada número de una lista dada.

# %% [markdown]
# ### Nota explicativa
# Se define una función lambda que suma 3 a cada número de una lista. Para aplicarlo a todos los elementos se usa `map()`.

# %%
sumar_tres = lambda lista: list(map(lambda numero: numero + 3, lista))

# %%
print("#15", sumar_tres([1, 2, 3, 4]))
# Out:
# #15 [4, 5, 6, 7]

# %% [markdown]
# ## Ejercicio 16
#
# Escribe una función que tome una cadena de texto y un número entero `n` como parámetros y devuelva una lista de todas las palabras que sean más largas que `n`. Usa la función `filter()`.

# %% [markdown]
# ### Nota explicativa
# Primero se separa el texto en palabras con `split()`. Después se utiliza `filter()` para quedarse solo con las palabras cuya longitud sea mayor que el valor `n`.

# %%
def palabras_mas_largas_que(texto, n):
    palabras = texto.split()
    return list(filter(lambda palabra: len(palabra) > n, palabras))

# %%
print("#16", palabras_mas_largas_que("Python es bastante util para datos", 5))
# Out:
# #16 ['Python', 'bastante']

# %% [markdown]
# ## Ejercicio 17
#
# Crea una función que tome una lista de dígitos y devuelva el número correspondiente. Por ejemplo, `[5,7,2]` corresponde al número `572`. Usa la función `reduce()`.

# %% [markdown]
# ### Nota explicativa
# Se usa `reduce()` para ir construyendo el número completo a partir de los dígitos. La lógica es multiplicar el acumulado por 10 y sumarle el siguiente dígito, de forma que el número se vaya formando paso a paso.

# %%
def digitos_a_numero(lista_digitos):
    return reduce(lambda acumulado, digito: acumulado * 10 + digito, lista_digitos, 0)

# %%
print("#17", digitos_a_numero([5, 7, 2]))
# Out:
# #17 572

# %% [markdown]
# ## Ejercicio 18
#
# Escribe un programa en Python que cree una lista de diccionarios con información de estudiantes (nombre, edad, calificación) y use `filter` para extraer a los estudiantes con una calificación mayor o igual a 90.

# %% [markdown]
# ### Nota explicativa
# Se trabaja con una lista de diccionarios. La función usa `filter()` para seleccionar solo aquellos estudiantes cuya clave `"calificacion"` sea mayor o igual a 90.

# %%
def estudiantes_destacados(estudiantes):
    return list(filter(lambda estudiante: estudiante["calificacion"] >= 90, estudiantes))

# %%
print("#18", estudiantes_destacados([
    {"nombre": "Ana", "edad": 20, "calificacion": 95},
    {"nombre": "Luis", "edad": 21, "calificacion": 88},
    {"nombre": "Marta", "edad": 22, "calificacion": 90}
]))
# Out:
# #18 [{'nombre': 'Ana', 'edad': 20, 'calificacion': 95}, {'nombre': 'Marta', 'edad': 22, 'calificacion': 90}]

# %% [markdown]
# ## Ejercicio 19
#
# Crea una función lambda que filtre los números impares de una lista dada.

# %% [markdown]
# ### Nota explicativa
# Se define una función lambda que utiliza `filter()` para quedarse únicamente con los números impares. Un número es impar cuando el resto de dividirlo entre 2 es distinto de 0.

# %%
filtrar_impares = lambda lista: list(filter(lambda numero: numero % 2 != 0, lista))

# %%
print("#19", filtrar_impares([1, 2, 3, 4, 5, 6, 7]))
# Out:
# #19 [1, 3, 5, 7]

# %% [markdown]
# ## Ejercicio 20
#
# Para una lista con elementos de tipo integer y string, obtén una nueva lista solo con los valores int. Usa la función `filter()`.

# %% [markdown]
# ### Nota explicativa
# Se utiliza `filter()` junto con `isinstance()` para comprobar el tipo de cada elemento de la lista. Así se devuelven únicamente los valores que sean enteros.

# %%
def solo_enteros(lista_mixta):
    return list(filter(lambda elemento: isinstance(elemento, int), lista_mixta))

# %%
print("#20", solo_enteros([1, "hola", 3, "python", 7, 2.5]))
# Out:
# #20 [1, 3, 7]

# %% [markdown]
# ## Ejercicio 21
# Crea una función que calcule el cubo de un número dado mediante una función lambda.

# %% [markdown]
# ### Nota explicativa
# Se define una función lambda para calcular el cubo de un número. El cubo se obtiene multiplicando el número por sí mismo tres veces.

# %%
calcular_cubo = lambda numero: numero ** 3

# %%
print("#21", calcular_cubo(4))
# Out:
# #21 64

# %% [markdown]
# ## Ejercicio 22
# Dada una lista numérica, obtén el producto total de los valores. Usa la función reduce().

# %% [markdown]
# ### Nota explicativa
# Se usa `reduce()` para multiplicar todos los números de una lista y obtener un único resultado final. El acumulador va guardando el producto parcial en cada paso.

# %%
def producto_total(lista_numeros):
    return reduce(lambda acumulado, numero: acumulado * numero, lista_numeros, 1)

# %%
print("#22", producto_total([2, 3, 4]))
# Out:
# #22 24

# %% [markdown]
# ## Ejercicio 23
# Concatena una lista de palabras. Usa la función reduce().

# %% [markdown]
# ### Nota explicativa
# Se usa `reduce()` para unir todas las palabras de una lista en una sola cadena de texto. Se van concatenando una a una.

# %%
def concatenar_palabras(lista_palabras):
    return reduce(lambda acumulado, palabra: acumulado + palabra, lista_palabras, "")

# %%
print("#23", concatenar_palabras(["Hola", " ", "mundo", "!"]))
# Out:
# #23 Hola mundo!

# %% [markdown]
# ## Ejercicio 24
# Calcula la diferencia total en los valores de una lista. Usa la función reduce().

# %% [markdown]
# ### Nota explicativa
# Se calcula la diferencia total de una lista usando `reduce()`. La operación se hace de forma acumulativa, restando cada elemento al resultado anterior.

# %%
def diferencia_total(lista_numeros):
    if not lista_numeros:
        return 0
    return reduce(lambda acumulado, numero: acumulado - numero, lista_numeros[1:], lista_numeros[0])

# %%
print("#24", diferencia_total([20, 5, 3]))
# Out:
# #24 12

# %% [markdown]
# ## Ejercicio 25
# Crea una función que cuente el número de caracteres en una cadena de texto dada.

# %% [markdown]
# ### Nota explicativa
# Este ejercicio es directo: se cuenta el número de caracteres de una cadena usando `len()`.

# %%
def contar_caracteres(texto):
    return len(texto)

# %%
print("#25", contar_caracteres("Python"))
# Out:
# #25 6

# %% [markdown]
# ## Ejercicio 26
# Crea una función lambda que calcule el resto de la división entre dos números dados.

# %% [markdown]
# ### Nota explicativa
# Se usa una función lambda para calcular el resto de una división. El operador `%` devuelve el resto.

# %%
calcular_resto = lambda numero1, numero2: numero1 % numero2

# %%
print("#26", calcular_resto(10, 3))
# Out:
# #26 1

# %% [markdown]
# ## Ejercicio 27
# Crea una función que calcule el promedio de una lista de números.

# %% [markdown]
# ### Nota explicativa
# Se calcula el promedio de una lista sumando todos sus valores y dividiendo entre la cantidad de elementos. Si la lista está vacía, se devuelve 0 para evitar error.

# %%
def promedio_lista(lista_numeros):
    if len(lista_numeros) == 0:
        return 0
    return sum(lista_numeros) / len(lista_numeros)

# %%
print("#27", promedio_lista([4, 8, 10]))
# Out:
# #27 7.333333333333333

# %% [markdown]
# ## Ejercicio 28
# Crea una función que busque y devuelva el primer elemento duplicado en una lista dada.

# %% [markdown]
# ### Nota explicativa
# Se busca el primer elemento duplicado recorriendo la lista y guardando los elementos ya vistos en un conjunto. Si un elemento aparece otra vez, se devuelve inmediatamente.

# %%
def primer_duplicado(lista):
    vistos = set()

    for elemento in lista:
        if elemento in vistos:
            return elemento
        vistos.add(elemento)

    return None

# %%
print("#28", primer_duplicado([1, 2, 3, 4, 2, 5]))
# Out:
# #28 2

# %% [markdown]
# ## Ejercicio 29
# Crea una función que convierta una variable en una cadena de texto y enmascare todos los caracteres con el carácter '#' excepto los últimos cuatro.

# %% [markdown]
# ### Nota explicativa
# Primero se convierte el valor a texto con `str()`. Después se reemplazan todos los caracteres por `#`, excepto los últimos cuatro, que se conservan visibles.

# %%
def enmascarar_variable(valor):
    texto = str(valor)

    if len(texto) <= 4:
        return texto

    return "#" * (len(texto) - 4) + texto[-4:]

# %%
print("#29", enmascarar_variable("123456789"))
print("#29", enmascarar_variable(987654321))
# Out:
# #29 #####6789
# #29 #####4321

# %% [markdown]
# ## Ejercicio 30
# Crea una función que determine si dos palabras son anagramas, es decir, si están formadas por las mismas letras pero en diferente orden.

# %% [markdown]
# ### Nota explicativa
# Dos palabras son anagramas si contienen las mismas letras en distinto orden. Para comprobarlo, se pasan a minúsculas, se ordenan sus caracteres y se comparan los resultados.

# %%
def son_anagramas(palabra1, palabra2):
    palabra1_ordenada = sorted(palabra1.lower())
    palabra2_ordenada = sorted(palabra2.lower())
    return palabra1_ordenada == palabra2_ordenada

# %%
print("#30", son_anagramas("roma", "amor"))
print("#30", son_anagramas("python", "java"))
# Out:
# #30 True
# #30 False

# %% [markdown]
# ## Ejercicio 31
# Crea una función que solicite al usuario ingresar una lista de nombres y luego un nombre para buscar en esa lista. Si el nombre está en la lista, imprime un mensaje indicando que fue encontrado; de lo contrario, lanza una excepción.

# %% [markdown]
# ### Nota explicativa
# Se usa `input()` y por eso conviene probarlo manualmente. Primero se pide una lista de nombres separada por comas y después un nombre a buscar. Si no está en la lista, se lanza una excepción.

# %%
def buscar_nombre_en_lista():
    try:
        nombres = input("Introduce una lista de nombres separados por comas: ").split(",")
        nombres = [nombre.strip() for nombre in nombres]

        nombre_buscado = input("Introduce el nombre que quieres buscar: ").strip()

        if nombre_buscado in nombres:
            print(f"El nombre {nombre_buscado} fue encontrado en la lista.")
        else:
            raise ValueError(f"El nombre {nombre_buscado} no fue encontrado en la lista.")
    except ValueError as error:
        print(f"Error: {error}")

# %%
buscar_nombre_en_lista()
# Out:
# Error: El nombre adrian no fue encontrado en la lista.

# %%
print("Hola mundo por 31 vez !!!")
# Out:
# Hola mundo por 31 vez !!!

# %% [markdown]
# ## Ejercicio 32
# Crea una función que tome un nombre completo y una lista de empleados, busque el nombre en la lista y devuelva el puesto del empleado si se encuentra; de lo contrario, devuelve un mensaje indicando que la persona no trabaja aquí.

# %% [markdown]
# ### Nota explicativa
# Se busca un nombre completo dentro de una lista de empleados. Si se encuentra, se devuelve su puesto; si no, se devuelve un mensaje indicando que no trabaja allí.

# %%
def buscar_puesto(nombre_completo, empleados):
    for empleado in empleados:
        if empleado["nombre"] == nombre_completo:
            return empleado["puesto"]

    return "La persona no trabaja aquí."

# %%
empleados_prueba = [
    {"nombre": "Ana López", "puesto": "Analista"},
    {"nombre": "Luis Pérez", "puesto": "Desarrollador"},
    {"nombre": "Marta Ruiz", "puesto": "Data Scientist"}
]

print("#32", buscar_puesto("Marta Ruiz", empleados_prueba))
print("#32", buscar_puesto("Pedro Gómez", empleados_prueba))
# Out:
# #32 Data Scientist
# #32 La persona no trabaja aquí.

# %% [markdown]
# ## Ejercicio 33
# Crea una función lambda que sume elementos correspondientes de dos listas dadas.

# %% [markdown]
# ### Nota explicativa
# Se define una función lambda que suma los elementos correspondientes de dos listas usando `map()`. El resultado final se convierte en lista.

# %%
sumar_listas = lambda lista1, lista2: list(map(lambda x, y: x + y, lista1, lista2))

# %%
print("#33", sumar_listas([1, 2, 3], [4, 5, 6]))
# Out:
# #33 [5, 7, 9]

# %% [markdown]
# ## Ejercicio 34
# Crea la clase Arbol
#
# Define un árbol genérico con un tronco y ramas como atributos.
#
# Métodos disponibles: crecer_tronco, nueva_rama, crecer_ramas, quitar_rama, info_arbol.
#
# Código a seguir:
# Inicializar un árbol con un tronco de longitud 1 y una lista vacía de ramas.
# Implementar el método crecer_tronco para aumentar la longitud del tronco en una unidad.
# Implementar el método nueva_rama para agregar una nueva rama de longitud 1 a la lista de ramas.
# Implementar el método crecer_ramas para aumentar en una unidad la longitud de todas las ramas existentes.
# Implementar el método quitar_rama para eliminar una rama en una posición específica.
# Implementar el método info_arbol para devolver información sobre la longitud del tronco, el número de ramas y sus longitudes.
#
# Caso de uso:
# a. Crear un árbol.
# b. Hacer crecer el tronco una unidad.
# c. Añadir una nueva rama.
# d. Hacer crecer todas las ramas una unidad.
# e. Añadir dos nuevas ramas.
# f. Retirar la rama situada en la posición 2.
# g. Obtener información sobre el árbol.

# %% [markdown]
# ## Ejercicio 35
# Crea la clase UsuarioBanco
#
# Representa a un usuario de un banco con su nombre, saldo y si tiene o no cuenta corriente.
#
# Métodos: retirar_dinero, transferir_dinero, agregar_dinero.
#
# Código a seguir:
# Inicializar un usuario con nombre, saldo y un indicador (True o False) de cuenta corriente.
# Implementar retirar_dinero para sustraer dinero del saldo, lanzando un error si no es posible.
# Implementar transferir_dinero para transferir dinero desde otro usuario, lanzando un error en caso de fallo.
# Implementar agregar_dinero para aumentar el saldo del usuario.
#
# Caso de uso:
# a. Crear dos usuarios: "Alicia" con saldo inicial de 100 y "Bob" con saldo inicial de 50, ambos con cuenta corriente.
# b. Agregar 20 unidades al saldo de Bob.
# c. Transferir 80 unidades de Bob a Alicia.
# d. Retirar 50 unidades del saldo de Alicia.

# %% [markdown]
# ## Ejercicio 36
# Crea una función llamada procesar_texto
#
# Procesa un texto según la opción especificada: contar_palabras, reemplazar_palabras o eliminar_palabra.
#
# Código a seguir:
# Crear una función contar_palabras que cuente el número de veces que aparece cada palabra en el texto y devuelva un diccionario.
# Crear una función reemplazar_palabras para sustituir una palabra_original por una palabra_nueva en el texto y devolver el texto modificado.
# Crear una función eliminar_palabra que elimine una palabra del texto y devuelva el texto sin ella.
# Crear la función procesar_texto que reciba un texto, una opción ("contar", "reemplazar", "eliminar") y un número variable de argumentos según la opción elegida.
#
# Caso de uso:
# Verificar el funcionamiento completo de procesar_texto.

# %% [markdown]
# ## Ejercicio 37
# Genera un programa que nos indique si es de noche, de día o de tarde según la hora proporcionada por el usuario.

# %% [markdown]
# ## Ejercicio 38
# Escribe un programa que determine qué calificación en texto tiene un alumno según su calificación numérica.
#
# Reglas:
# 0 - 69: insuficiente
# 70 - 79: bien
# 80 - 89: muy bien
# 90 - 100: excelente

# %% [markdown]
# ## Ejercicio 39
# Escribe una función que tome dos parámetros: figura (una cadena que puede ser "rectangulo", "circulo" o "triangulo") y datos (una tupla con los datos necesarios para calcular el área de la figura).

# %% [markdown]
# ## Ejercicio 40
# Escribe un programa en Python que utilice condicionales para determinar el monto final de una compra en una tienda en línea, después de aplicar un descuento. El programa debe:
#
# a. Solicitar al usuario el precio original de un artículo.
# b. Preguntar si tiene un cupón de descuento (respuesta sí o no).
# c. Si la respuesta es sí, solicitar el valor del cupón de descuento.
# d. Aplicar el descuento al precio original, siempre que el valor del cupón sea válido (mayor a cero).
# e. Mostrar el precio final de la compra, considerando o no el descuento.
# f. Usar estructuras de control de flujo (if, elif, else) para llevar a cabo las acciones.
